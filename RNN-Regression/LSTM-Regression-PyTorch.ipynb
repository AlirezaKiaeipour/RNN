# %% [markdown]
# ## Import Libraries

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Sin Signal

# %%
N = 2000
t = np.arange(0,N)
sin_data = np.sin(0.02*t)/2 + np.random.uniform(-0.05,0.05,N)
plt.figure(figsize=(20,4))
plt.plot(sin_data)
plt.show()

# %% [markdown]
# ## Convert Signal To Dataset

# %%
def convertSignalToDataset(signal,step):
    X,Y = [],[]
    for i in range(len(signal)-step):
        j = i+step
        X.append(signal[i:j])
        Y.append(signal[j])
        
    X,Y = np.array(X), np.array(Y)
    return torch.Tensor(X[...,np.newaxis]), torch.Tensor(Y[...,np.newaxis])

# %%
X_train = sin_data[:1500]
X_test = sin_data[1500:]

# %%
X_train, Y_train = convertSignalToDataset(X_train,15)
X_test , Y_test = convertSignalToDataset(X_test,15)

# %% [markdown]
# ## Model
# ## LSTM

# %%
class LSTM(nn.Module):
    def __init__(self,input_size,hidden_size,num_layers,num_classes):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size=input_size,hidden_size=hidden_size,num_layers=num_layers,batch_first=True)
        self.fc = nn.Linear(hidden_size,num_classes)
        
    def forward(self,x):
        h_0 = torch.zeros(self.num_layers,x.size(0),self.hidden_size)
        c_0 = torch.zeros(self.num_layers,x.size(0),self.hidden_size)
        
        x,_ = self.lstm(x,(h_0,c_0))
        x = x[:,-1,:]
        x = self.fc(x)
        
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = LSTM(input_size=1,hidden_size=64,num_layers=1,num_classes=1).to(device)

# %%
optimizer = torch.optim.Adam(model.parameters(),lr=0.001)
loss_function = nn.MSELoss()

# %%
for epoch in range(250):
    model.train()
    optimizer.zero_grad()
    predict = model(X_train)
    loss = loss_function(predict,Y_train)
    loss.backward()
    optimizer.step()
    print(f"Epochs: {epoch+1}, Loss: {loss}")
# Out:
# Epochs: 1, Loss: 0.1329648643732071
# Epochs: 2, Loss: 0.1295013725757599
# Epochs: 3, Loss: 0.12627394497394562
# Epochs: 4, Loss: 0.12324920296669006
# Epochs: 5, Loss: 0.12039005011320114
# Epochs: 6, Loss: 0.11765303462743759
# Epochs: 7, Loss: 0.1149887889623642
# Epochs: 8, Loss: 0.1123460978269577
# Epochs: 9, Loss: 0.10967613011598587
# Epochs: 10, Loss: 0.10693530738353729
# Epochs: 11, Loss: 0.10408656299114227
# Epochs: 12, Loss: 0.10109880566596985
# Epochs: 13, Loss: 0.09794497489929199
# Epochs: 14, Loss: 0.09459991008043289
# Epochs: 15, Loss: 0.09103856980800629
# Epochs: 16, Loss: 0.08723492175340652
# Epochs: 17, Loss: 0.08316074311733246
# Epochs: 18, Loss: 0.07878423482179642
# Epochs: 19, Loss: 0.07406790554523468
# Epochs: 20, Loss: 0.06896604597568512
# Epochs: 21, Loss: 0.06342320889234543
# Epochs: 22, Loss: 0.05737733095884323
# Epochs: 23, Loss: 0.050773851573467255
# Epochs: 24, Loss: 0.04359395056962967
# Epochs: 25, Loss: 0.035898685455322266
# Epochs: 26, Loss: 0.02788936160504818
# Epochs: 27, Loss: 0.019976314157247543
# Epochs: 28, Loss: 0.012838736176490784
# Epochs: 29, Loss: 0.007459116633981466
# Epochs: 30, Loss: 0.005027059931308031
# Epochs: 31, Loss: 0.006390563677996397
# Epochs: 32, Loss: 0.011282353661954403
# Epochs: 33, Loss: 0.016257362440228462
# Epochs: 34, Loss: 0.01715780235826969
# Epochs: 35, Loss: 0.01457150001078844
# Epochs: 36, Loss: 0.010694998316466808
# Epochs: 37, Loss: 0.007223598193377256
# Epochs: 38, Loss: 0.0049580978229641914
# Epochs: 39, Loss: 0.004007289186120033
# Epochs: 40, Loss: 0.004094127099961042
# Epochs: 41, Loss: 0.004796894267201424
# Epochs: 42, Loss: 0.005712414626032114
# Epochs: 43, Loss: 0.006541135720908642
# Epochs: 44, Loss: 0.0071049840189516544
# Epochs: 45, Loss: 0.007327738218009472
# Epochs: 46, Loss: 0.00720584113150835
# Epochs: 47, Loss: 0.0067840381525456905
# Epochs: 48, Loss: 0.006139209493994713
# Epochs: 49, Loss: 0.005370364058762789
# Epochs: 50, Loss: 0.004590724129229784
# Epochs: 51, Loss: 0.003917098045349121
# Epochs: 52, Loss: 0.0034524351358413696
# Epochs: 53, Loss: 0.003260702360421419
# Epochs: 54, Loss: 0.0033403534907847643
# Epochs: 55, Loss: 0.003611696185544133
# Epochs: 56, Loss: 0.003935484681278467
# Epochs: 57, Loss: 0.004164653830230236
# Epochs: 58, Loss: 0.004204560536891222
# Epochs: 59, Loss: 0.004046235699206591
# Epochs: 60, Loss: 0.0037562174256891012
# Epochs: 61, Loss: 0.0034358548000454903
# Epochs: 62, Loss: 0.003176287980750203
# Epochs: 63, Loss: 0.0030291895382106304
# Epochs: 64, Loss: 0.0029998242389410734
# Epochs: 65, Loss: 0.003057860303670168
# Epochs: 66, Loss: 0.003156244521960616
# Epochs: 67, Loss: 0.0032490945886820555
# Epochs: 68, Loss: 0.0033035213127732277
# Epochs: 69, Loss: 0.003304478246718645
# Epochs: 70, Loss: 0.0032541656401008368
# Epochs: 71, Loss: 0.003168098395690322
# Epochs: 72, Loss: 0.00306942337192595
# Epochs: 73, Loss: 0.002982435282319784
# Epochs: 74, Loss: 0.0029260795563459396
# Epochs: 75, Loss: 0.0029086696449667215
# Epochs: 76, Loss: 0.0029255873523652554
# Epochs: 77, Loss: 0.002961411140859127
# Epochs: 78, Loss: 0.0029962428379803896
# Epochs: 79, Loss: 0.0030136252753436565
# Epochs: 80, Loss: 0.0030063497833907604
# Epochs: 81, Loss: 0.0029777013696730137
# Epochs: 82, Loss: 0.0029383187647908926
# Epochs: 83, Loss: 0.0029008500277996063
# Epochs: 84, Loss: 0.0028749534394592047
# Epochs: 85, Loss: 0.0028644169215112925
# Epochs: 86, Loss: 0.002866990864276886
# Epochs: 87, Loss: 0.002876423066481948
# Epochs: 88, Loss: 0.002885471098124981
# Epochs: 89, Loss: 0.0028885758947581053
# Epochs: 90, Loss: 0.0028833316173404455
# Epochs: 91, Loss: 0.0028705995064228773
# Epochs: 92, Loss: 0.002853590063750744
# Epochs: 93, Loss: 0.0028364460449665785
# Epochs: 94, Loss: 0.0028227742295712233
# Epochs: 95, Loss: 0.0028145054820924997
# Epochs: 96, Loss: 0.002811396960169077
# Epochs: 97, Loss: 0.0028113597072660923
# Epochs: 98, Loss: 0.002811491722241044
# Epochs: 99, Loss: 0.0028093447908759117
# Epochs: 100, Loss: 0.002803825307637453
# Epochs: 101, Loss: 0.0027953796088695526
# Epochs: 102, Loss: 0.002785520628094673
# Epochs: 103, Loss: 0.00277604628354311
# Epochs: 104, Loss: 0.002768308389931917
# Epochs: 105, Loss: 0.002762779826298356
# Epochs: 106, Loss: 0.002759024500846863
# Epochs: 107, Loss: 0.002756019588559866
# Epochs: 108, Loss: 0.002752656117081642
# Epochs: 109, Loss: 0.002748184371739626
# Epochs: 110, Loss: 0.0027424313593655825
# Epochs: 111, Loss: 0.002735747955739498
# Epochs: 112, Loss: 0.002728774445131421
# Epochs: 113, Loss: 0.0027221532072871923
# Epochs: 114, Loss: 0.0027162875048816204
# Epochs: 115, Loss: 0.0027112208772450686
# Epochs: 116, Loss: 0.002706666709855199
# Epochs: 117, Loss: 0.002702172612771392
# Epochs: 118, Loss: 0.0026973350904881954
# Epochs: 119, Loss: 0.0026919653173536062
# Epochs: 120, Loss: 0.0026861289516091347
# Epochs: 121, Loss: 0.002680069301277399
# Epochs: 122, Loss: 0.0026740715838968754
# Epochs: 123, Loss: 0.0026683411560952663
# Epochs: 124, Loss: 0.0026629336643964052
# Epochs: 125, Loss: 0.0026577545795589685
# Epochs: 126, Loss: 0.0026526234578341246
# Epochs: 127, Loss: 0.0026473626494407654
# Epochs: 128, Loss: 0.0026418745983392
# Epochs: 129, Loss: 0.002636168384924531
# Epochs: 130, Loss: 0.0026303348131477833
# Epochs: 131, Loss: 0.002624492160975933
# Epochs: 132, Loss: 0.002618733560666442
# Epochs: 133, Loss: 0.002613091142848134
# Epochs: 134, Loss: 0.0026075339410454035
# Epochs: 135, Loss: 0.002601989544928074
# Epochs: 136, Loss: 0.0025963829830288887
# Epochs: 137, Loss: 0.0025906746741384268
# Epochs: 138, Loss: 0.0025848683435469866
# Epochs: 139, Loss: 0.002579005667939782
# Epochs: 140, Loss: 0.0025731362402439117
# Epochs: 141, Loss: 0.002567296614870429
# Epochs: 142, Loss: 0.0025614947080612183
# Epochs: 143, Loss: 0.0025557116605341434
# Epochs: 144, Loss: 0.002549912082031369
# Epochs: 145, Loss: 0.002544064773246646
# Epochs: 146, Loss: 0.0025381548330187798
# Epochs: 147, Loss: 0.002532188780605793
# Epochs: 148, Loss: 0.0025261850096285343
# Epochs: 149, Loss: 0.002520165638998151
# Epochs: 150, Loss: 0.0025141441728919744
# Epochs: 151, Loss: 0.002508120611310005
# Epochs: 152, Loss: 0.0025020847097039223
# Epochs: 153, Loss: 0.002496022265404463
# Epochs: 154, Loss: 0.0024899225682020187
# Epochs: 155, Loss: 0.00248378305695951
# Epochs: 156, Loss: 0.0024776095524430275
# Epochs: 157, Loss: 0.0024714122992008924
# Epochs: 158, Loss: 0.0024651980493217707
# Epochs: 159, Loss: 0.0024589686654508114
# Epochs: 160, Loss: 0.0024527201894670725
# Epochs: 161, Loss: 0.0024464454036206007
# Epochs: 162, Loss: 0.0024401373229920864
# Epochs: 163, Loss: 0.0024337926879525185
# Epochs: 164, Loss: 0.0024274117313325405
# Epochs: 165, Loss: 0.0024209986440837383
# Epochs: 166, Loss: 0.0024145578499883413
# Epochs: 167, Loss: 0.002408090513199568
# Epochs: 168, Loss: 0.0024015968665480614
# Epochs: 169, Loss: 0.002395074116066098
# Epochs: 170, Loss: 0.002388519002124667
# Epochs: 171, Loss: 0.0023819298949092627
# Epochs: 172, Loss: 0.002375307260081172
# Epochs: 173, Loss: 0.0023686515633016825
# Epochs: 174, Loss: 0.002361964900046587
# Epochs: 175, Loss: 0.0023552468046545982
# Epochs: 176, Loss: 0.0023484965786337852
# Epochs: 177, Loss: 0.0023417118936777115
# Epochs: 178, Loss: 0.0023348904214799404
# Epochs: 179, Loss: 0.002328030299395323
# Epochs: 180, Loss: 0.002321130596101284
# Epochs: 181, Loss: 0.002314192010089755
# Epochs: 182, Loss: 0.002307214541360736
# Epochs: 183, Loss: 0.0023001988884061575
# Epochs: 184, Loss: 0.002293143654242158
# Epochs: 185, Loss: 0.0022860481403768063
# Epochs: 186, Loss: 0.002278911415487528
# Epochs: 187, Loss: 0.0022717320825904608
# Epochs: 188, Loss: 0.0022645099088549614
# Epochs: 189, Loss: 0.0022572444286197424
# Epochs: 190, Loss: 0.002249934710562229
# Epochs: 191, Loss: 0.002242580521851778
# Epochs: 192, Loss: 0.002235179068520665
# Epochs: 193, Loss: 0.0022277298849076033
# Epochs: 194, Loss: 0.0022202308755367994
# Epochs: 195, Loss: 0.002212681109085679
# Epochs: 196, Loss: 0.002205079421401024
# Epochs: 197, Loss: 0.0021974248811602592
# Epochs: 198, Loss: 0.0021897165570408106
# Epochs: 199, Loss: 0.002181953750550747
# Epochs: 200, Loss: 0.00217413529753685
# Epochs: 201, Loss: 0.002166259801015258
# Epochs: 202, Loss: 0.0021583258640021086
# Epochs: 203, Loss: 0.0021503320895135403
# Epochs: 204, Loss: 0.002142277779057622
# Epochs: 205, Loss: 0.002134160604327917
# Epochs: 206, Loss: 0.0021259791683405638
# Epochs: 207, Loss: 0.0021177318412810564
# Epochs: 208, Loss: 0.0021094162948429585
# Epochs: 209, Loss: 0.0021010306663811207
# Epochs: 210, Loss: 0.002092573558911681
# Epochs: 211, Loss: 0.0020840431097894907
# Epochs: 212, Loss: 0.0020754369907081127
# Epochs: 213, Loss: 0.0020667542703449726
# Epochs: 214, Loss: 0.00205799238756299
# Epochs: 215, Loss: 0.0020491499453783035
# Epochs: 216, Loss: 0.002040224615484476
# Epochs: 217, Loss: 0.0020312145352363586
# Epochs: 218, Loss: 0.0020221173763275146
# Epochs: 219, Loss: 0.002012930577620864
# Epochs: 220, Loss: 0.00200365181080997
# Epochs: 221, Loss: 0.0019942782819271088
# Epochs: 222, Loss: 0.0019848071970045567
# Epochs: 223, Loss: 0.001975236227735877
# Epochs: 224, Loss: 0.0019655623473227024
# Epochs: 225, Loss: 0.0019557832274585962
# Epochs: 226, Loss: 0.001945896539837122
# Epochs: 227, Loss: 0.0019358992576599121
# Epochs: 228, Loss: 0.0019257887033745646
# Epochs: 229, Loss: 0.001915562548674643
# Epochs: 230, Loss: 0.0019052173011004925
# Epochs: 231, Loss: 0.001894750283099711
# Epochs: 232, Loss: 0.0018841585842892528
# Epochs: 233, Loss: 0.0018734390614554286
# Epochs: 234, Loss: 0.0018625882221385837
# Epochs: 235, Loss: 0.0018516036216169596
# Epochs: 236, Loss: 0.001840482116676867
# Epochs: 237, Loss: 0.0018292206805199385
# Epochs: 238, Loss: 0.0018178175669163465
# Epochs: 239, Loss: 0.0018062698654830456
# Epochs: 240, Loss: 0.0017945750150829554
# Epochs: 241, Loss: 0.0017827313859015703
# Epochs: 242, Loss: 0.0017707364168018103
# Epochs: 243, Loss: 0.001758588245138526
# Epochs: 244, Loss: 0.0017462855903431773
# Epochs: 245, Loss: 0.0017338269390165806
# Epochs: 246, Loss: 0.0017212113598361611
# Epochs: 247, Loss: 0.0017084386199712753
# Epochs: 248, Loss: 0.0016955094179138541
# Epochs: 249, Loss: 0.0016824246849864721
# Epochs: 250, Loss: 0.0016691857017576694

# %% [markdown]
# ## Predict

# %%
model.eval()
pred_train = model(X_train)
pred_train = pred_train.data.numpy()
pred_test = model(X_test)
pred_test = pred_test.data.numpy()
nan_data = np.ones((1500,1)) * np.nan
pred_test = np.concatenate((nan_data,pred_test),axis=0)

# %%
plt.figure(figsize=(18,5))
plt.plot(sin_data,label="Real")
plt.plot(pred_train,label="Train")
plt.plot(pred_test,label="Test")
plt.legend()
plt.show()
